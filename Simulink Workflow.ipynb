# %% [markdown]
# #### Task 1.
#
# The equations for a discrete PI controller are listed on the model. The design variables, $K_{p}$ and $K_{i}$, and the sample time, $T_{s}$, have been defined in the MATLAB workspace.
#
#
# Proportional-Integral Control:
# $y[k]$ = $y_{p}[k]$ + $y_{i}[k]$,
#
# where: $y_{p}[k]$ = $K_{p}e[k]$ and $y_{i}[k]$ = $K_{i}T_{s}e[k]$ + $y_{i}[k-1]$
#
# Add another Gain block to the model and set its value to $K_{i}$*$T_{s}$. Branch $e[k]$ and connect it to the Gain block you just created, to create the term $K_{i}T_{s}e[k]$.

# %% [markdown]
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# #### Task 2.
#
# Add the appropriate number of Unit Delay blocks to the model to represent the integrator term, $y_i[k−1]$. You do not need to make any connections yet.

# %% [markdown]
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# #### Task 3.
#
# As a reminder, it is helpful to create stubs and label the signals entering and leaving Unit Delay blocks.
#
# Create stubs on the Unit Delay block. Label the appropriate signals "yi_k" and "yi_kminus1".

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# #### Task 4.
#
# Use an Add block to sum the terms of the integrator equation, $K_{i}T_{s}e[k]$ + $y_{i}[k-1]$. Do not make any other connections yet.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# #### Task 5.
#
# Make the connections that complete the integrator equation $y_{i}[k]$ = $K_{i}T_{s}e[k]$ + $y_{i}[k-1]$. Do not connect $y_{p}[k]$ yet. Branch "yi_k" to the Signal Assessment block.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# #### Task 6.
#
# The controller output is the combined output of the proportional and integral terms: $y[k]$ = $y_{p}[k]$ + $y_{i}[k]$
#
# Add the signals $y_{p}[k]$ and $y_{i}[k]$ to create $y[k]$. Connect $y[k]$ to the input port of the House subsystem. Branch and connect the temperature, "meas_temp", to the Signal Assessment block.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# #### Task 7.
#
# The last step in modeling difference equations is to set any initial conditions and sample times of the Unit Delay blocks.
#
# Set the Sample time to $T_{s}$. Use the default Initial condition of 0.

# %% [markdown]
# ![image-3.png](attachment:image-3.png)
